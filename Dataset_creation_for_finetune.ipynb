# %%
import os
import json
import csv
import xml.etree.ElementTree as ET
import openai
import numpy as np
from collections import defaultdict
import tiktoken
import gradio as gr

# %%
# json_template = '{{"messages": [{{"role": "system", "content": "{system}"}}, {{"role": "user", "content": "{user}"}}, {{"role": "assistant", "content": "{assistant}"}}]}}'

# def create_csv_entry(xml_content, prompt):
#     root = ET.fromstring(xml_content)
#     text_element = root.find('TEXT')
#     if text_element is None or text_element.text is None:
#         raise ValueError("The TEXT element is missing or empty.")
#     original_text = text_element.text
#     censored_text = original_text
#     tags = sorted(root.findall('.//TAGS/*'), key=lambda x: int(x.get('start')), reverse=True)
#     for tag in tags:
#         start = int(tag.get('start'))
#         end = int(tag.get('end'))
#         censored_text = censored_text[:start] + "[censored]" + censored_text[end:]
#     return json_template.format(system=prompt, user=original_text, assistant=censored_text)
def create_csv_entry(xml_content, prompt):
    root = ET.fromstring(xml_content)
    text_element = root.find('TEXT')
    if text_element is None or text_element.text is None:
        raise ValueError("The TEXT element is missing or empty.")
    original_text = text_element.text.strip()
    censored_text = original_text
    tags = sorted(root.findall('.//TAGS/*'), key=lambda x: int(x.get('start')), reverse=True)
    for tag in tags:
        start = int(tag.get('start'))
        end = int(tag.get('end'))
        censored_text = censored_text[:start] + "[censored]" + censored_text[end:]

    # Use a dictionary to form the JSON structure.
    json_structure = {
        "messages": [
            {"role": "system", "content": prompt},
            {"role": "user", "content": original_text},
            {"role": "assistant", "content": censored_text}
        ]
    }
    
    # Convert the dictionary to a JSON string.
    json_string = json.dumps(json_structure, ensure_ascii=False, separators=(',', ':'))
    
    return json_string

# %%
def process_xml_directory(input_dir, output_csv_path, prompt):
    with open(output_csv_path, mode='w', newline='', encoding='utf-8') as file:
        for filename in os.listdir(input_dir):
            if filename.endswith('.xml'):
                file_path = os.path.join(input_dir, filename)
                with open(file_path, 'r', encoding='UTF-8') as xml_file:
                    xml_content = xml_file.read()
                
                try:
                    writer = csv.writer(file)
                    writer.writerow([create_csv_entry(xml_content, brief_prompt)]) 
                    print(f'Processed and wrote results for {filename}')
                except ET.ParseError as e:
                    print(f"Error parsing {filename}: {str(e)}")
                except Exception as e:
                    print(f"An error occurred with {filename}: {str(e)}")

# %%
brief_prompt = '''Task: Please anonymize the following clinical note. Replace all the Protected health information (PHI) text with the "[censored]".'''


detailed_prompt = '''Task: Please anonymize the following clinical note.

Specific Instructions: Replace all the following Protected health information (PHI) text with the '[censored]'.

1) Censor any string or substring that has name, including patients, doctors, any acronyms, initials, and medical titles

2) Censor any string or substring that indicate profession with any mentions of job titles, like medical staff professional names, such as 'M.D.' and 'Dr.'.

3) Censor any string or substring with location, including addresses, clinic names, hospital names, and any other possible location indicators, such as '920 River Street'.

4) Censor any string or substring that indicate age, such as "Over 80 years" or "Aged 70".

5) Censor any string or substring that indicate dates, including record dates, admit dates, decharge dates etc, such as '27/09/2090' or '07/06' or '2090-08-25'

6) Censor any string or substring with contact information, including phone numbers, email, fax, URLs and IP Addresses'''

# %%
# Use the function like this:
input_directory = '/Users/yashwanthys/PersonalProjects/ML_Proj/De-Identification/training-PHI-Gold-Set1'
output_csv_file = '/Users/yashwanthys/PersonalProjects/ML_Proj/De-Identification/fine_tuning/fine_tuning_brief_dataset.csv'

# Process the XML files and write results to a CSV file in JSON format
process_xml_directory(input_directory, output_csv_file, brief_prompt)
# Out:
# Processed and wrote results for 279-03.xml
# Processed and wrote results for 304-03.xml
# Processed and wrote results for 251-02.xml
# Processed and wrote results for 351-02.xml
# Processed and wrote results for 400-02.xml
# Processed and wrote results for 288-05.xml
# Processed and wrote results for 332-02.xml
# Processed and wrote results for 367-03.xml
# Processed and wrote results for 296-05.xml
# Processed and wrote results for 243-02.xml
# Processed and wrote results for 320-02.xml
# Processed and wrote results for 220-02.xml
# Processed and wrote results for 275-03.xml
# Processed and wrote results for 284-05.xml
# Processed and wrote results for 308-03.xml
# Processed and wrote results for 308-02.xml
# Processed and wrote results for 284-04.xml
# Processed and wrote results for 275-02.xml
# Processed and wrote results for 220-03.xml
# Processed and wrote results for 320-03.xml
# Processed and wrote results for 243-03.xml
# Processed and wrote results for 294-01.xml
# Processed and wrote results for 394-01.xml
# Processed and wrote results for 398-01.xml
# Processed and wrote results for 298-01.xml
# Processed and wrote results for 296-04.xml
# Processed and wrote results for 396-04.xml
# Processed and wrote results for 367-02.xml
# Processed and wrote results for 332-03.xml
# Processed and wrote results for 400-03.xml
# Processed and wrote results for 351-03.xml
# Processed and wrote results for 288-04.xml
# Processed and wrote results for 251-03.xml
# Processed and wrote results for 286-01.xml
# Processed and wrote results for 304-02.xml
# Processed and wrote results for 279-02.xml
# Processed and wrote results for 222-04.xml
# Processed and wrote results for 322-04.xml
# Processed and wrote results for 277-05.xml
# Processed and wrote results for 286-03.xml
# Processed and wrote results for 351-01.xml
# Processed and wrote results for 400-01.xml
# Processed and wrote results for 251-01.xml
# Processed and wrote results for 332-01.xml
# Processed and wrote results for 398-03.xml
# Processed and wrote results for 241-04.xml
# Processed and wrote results for 298-03.xml
# Processed and wrote results for 330-04.xml
# Processed and wrote results for 365-05.xml
# Processed and wrote results for 294-03.xml
# Processed and wrote results for 394-03.xml
# Processed and wrote results for 243-01.xml
# Processed and wrote results for 220-01.xml
# Processed and wrote results for 320-01.xml
# Processed and wrote results for 353-04.xml
# Processed and wrote results for 253-04.xml
# Processed and wrote results for 308-01.xml
# Processed and wrote results for 306-04.xml
# Processed and wrote results for 275-01.xml
# Processed and wrote results for 394-02.xml
# Processed and wrote results for 294-02.xml
# Processed and wrote results for 365-04.xml
# Processed and wrote results for 298-02.xml
# Processed and wrote results for 398-02.xml
# Processed and wrote results for 367-01.xml
# Processed and wrote results for 369-04.xml
# Processed and wrote results for 286-02.xml
# Processed and wrote results for 304-01.xml
# Processed and wrote results for 277-04.xml
# Processed and wrote results for 322-05.xml
# Processed and wrote results for 222-05.xml
# Processed and wrote results for 279-01.xml
# Processed and wrote results for 279-05.xml
# Processed and wrote results for 222-01.xml
# Processed and wrote results for 322-01.xml
# Processed and wrote results for 351-04.xml
# Processed and wrote results for 400-04.xml
# Processed and wrote results for 288-03.xml
# Processed and wrote results for 251-04.xml
# Processed and wrote results for 304-05.xml
# Processed and wrote results for 332-04.xml
# Processed and wrote results for 241-01.xml
# Processed and wrote results for 296-03.xml
# Processed and wrote results for 396-03.xml
# Processed and wrote results for 330-01.xml
# Processed and wrote results for 243-04.xml
# Processed and wrote results for 220-04.xml
# Processed and wrote results for 320-04.xml
# Processed and wrote results for 353-01.xml
# Processed and wrote results for 253-01.xml
# Processed and wrote results for 284-03.xml
# Processed and wrote results for 284-02.xml
# Processed and wrote results for 306-01.xml
# Processed and wrote results for 308-04.xml
# Processed and wrote results for 220-05.xml
# Processed and wrote results for 275-04.xml
# Processed and wrote results for 365-01.xml
# Processed and wrote results for 396-02.xml
# Processed and wrote results for 296-02.xml
# Processed and wrote results for 369-01.xml
# Processed and wrote results for 332-05.xml
# Processed and wrote results for 367-04.xml
# Processed and wrote results for 304-04.xml
# Processed and wrote results for 400-05.xml
# Processed and wrote results for 288-02.xml
# Processed and wrote results for 279-04.xml
# Processed and wrote results for 277-01.xml
# Processed and wrote results for 277-03.xml
# Processed and wrote results for 322-02.xml
# Processed and wrote results for 222-02.xml
# Processed and wrote results for 369-03.xml
# Processed and wrote results for 298-05.xml
# Processed and wrote results for 241-02.xml
# Processed and wrote results for 365-03.xml
# Processed and wrote results for 330-02.xml
# Processed and wrote results for 253-02.xml
# Processed and wrote results for 353-02.xml
# Processed and wrote results for 306-03.xml
# Processed and wrote results for 284-01.xml
# Processed and wrote results for 306-02.xml
# Processed and wrote results for 353-03.xml
# Processed and wrote results for 253-03.xml
# Processed and wrote results for 294-04.xml
# Processed and wrote results for 394-04.xml
# Processed and wrote results for 330-03.xml
# Processed and wrote results for 365-02.xml
# Processed and wrote results for 296-01.xml
# Processed and wrote results for 396-01.xml
# Processed and wrote results for 398-04.xml
# Processed and wrote results for 241-03.xml
# Processed and wrote results for 298-04.xml
# Processed and wrote results for 369-02.xml
# Processed and wrote results for 286-04.xml
# Processed and wrote results for 288-01.xml
# Processed and wrote results for 222-03.xml
# Processed and wrote results for 322-03.xml
# Processed and wrote results for 277-02.xml
# Processed and wrote results for 363-04.xml
# Processed and wrote results for 392-02.xml
# Processed and wrote results for 292-02.xml
# Processed and wrote results for 228-05.xml
# Processed and wrote results for 273-01.xml
# Processed and wrote results for 300-04.xml
# Processed and wrote results for 324-05.xml
# Processed and wrote results for 271-04.xml
# Processed and wrote results for 280-02.xml
# Processed and wrote results for 302-01.xml
# Processed and wrote results for 361-01.xml
# Processed and wrote results for 247-04.xml
# Processed and wrote results for 249-01.xml
# Processed and wrote results for 334-01.xml
# Processed and wrote results for 357-01.xml
# Processed and wrote results for 257-01.xml
# Processed and wrote results for 259-04.xml
# Processed and wrote results for 359-04.xml
# Processed and wrote results for 280-03.xml
# Processed and wrote results for 224-04.xml
# Processed and wrote results for 324-04.xml
# Processed and wrote results for 355-04.xml
# Processed and wrote results for 300-05.xml
# Processed and wrote results for 328-04.xml
# Processed and wrote results for 228-04.xml
# Processed and wrote results for 226-01.xml
# Processed and wrote results for 326-01.xml
# Processed and wrote results for 292-03.xml
# Processed and wrote results for 392-03.xml
# Processed and wrote results for 338-01.xml
# Processed and wrote results for 336-04.xml
# Processed and wrote results for 338-03.xml
# Processed and wrote results for 292-01.xml
# Processed and wrote results for 392-01.xml
# Processed and wrote results for 226-03.xml
# Processed and wrote results for 326-03.xml
# Processed and wrote results for 273-02.xml
# Processed and wrote results for 282-04.xml
# Processed and wrote results for 280-01.xml
# Processed and wrote results for 302-02.xml
# Processed and wrote results for 357-03.xml
# Processed and wrote results for 257-03.xml
# Processed and wrote results for 334-03.xml
# Processed and wrote results for 361-02.xml
# Processed and wrote results for 290-04.xml
# Processed and wrote results for 249-03.xml
# Processed and wrote results for 249-02.xml
# Processed and wrote results for 361-03.xml
# Processed and wrote results for 334-02.xml
# Processed and wrote results for 257-02.xml
# Processed and wrote results for 357-02.xml
# Processed and wrote results for 302-03.xml
# Processed and wrote results for 273-03.xml
# Processed and wrote results for 326-02.xml
# Processed and wrote results for 226-02.xml
# Processed and wrote results for 338-02.xml
# Processed and wrote results for 363-02.xml
# Processed and wrote results for 336-03.xml
# Processed and wrote results for 292-04.xml
# Processed and wrote results for 392-04.xml
# Processed and wrote results for 328-03.xml
# Processed and wrote results for 228-03.xml
# Processed and wrote results for 355-03.xml
# Processed and wrote results for 255-03.xml
# Processed and wrote results for 282-01.xml
# Processed and wrote results for 300-02.xml
# Processed and wrote results for 271-02.xml
# Processed and wrote results for 224-03.xml
# Processed and wrote results for 324-03.xml
# Processed and wrote results for 259-03.xml
# Processed and wrote results for 359-03.xml
# Processed and wrote results for 280-04.xml
# Processed and wrote results for 247-03.xml
# Processed and wrote results for 290-01.xml
# Processed and wrote results for 247-02.xml
# Processed and wrote results for 359-02.xml
# Processed and wrote results for 259-02.xml
# Processed and wrote results for 324-02.xml
# Processed and wrote results for 224-02.xml
# Processed and wrote results for 271-03.xml
# Processed and wrote results for 300-03.xml
# Processed and wrote results for 255-02.xml
# Processed and wrote results for 355-02.xml
# Processed and wrote results for 228-02.xml
# Processed and wrote results for 328-02.xml
# Processed and wrote results for 292-05.xml
# Processed and wrote results for 336-02.xml
# Processed and wrote results for 363-03.xml
# Processed and wrote results for 363-01.xml
# Processed and wrote results for 338-05.xml
# Processed and wrote results for 273-04.xml
# Processed and wrote results for 326-05.xml
# Processed and wrote results for 226-05.xml
# Processed and wrote results for 282-02.xml
# Processed and wrote results for 300-01.xml
# Processed and wrote results for 271-01.xml
# Processed and wrote results for 357-05.xml
# Processed and wrote results for 302-04.xml
# Processed and wrote results for 361-04.xml
# Processed and wrote results for 290-02.xml
# Processed and wrote results for 290-03.xml
# Processed and wrote results for 249-04.xml
# Processed and wrote results for 247-01.xml
# Processed and wrote results for 334-04.xml
# Processed and wrote results for 361-05.xml
# Processed and wrote results for 259-01.xml
# Processed and wrote results for 359-01.xml
# Processed and wrote results for 357-04.xml
# Processed and wrote results for 257-04.xml
# Processed and wrote results for 224-01.xml
# Processed and wrote results for 324-01.xml
# Processed and wrote results for 282-03.xml
# Processed and wrote results for 355-01.xml
# Processed and wrote results for 255-01.xml
# Processed and wrote results for 226-04.xml
# Processed and wrote results for 326-04.xml
# Processed and wrote results for 328-01.xml
# Processed and wrote results for 273-05.xml
# Processed and wrote results for 228-01.xml
# Processed and wrote results for 336-01.xml
# Processed and wrote results for 338-04.xml
# Processed and wrote results for 364-04.xml
# Processed and wrote results for 331-05.xml
# Processed and wrote results for 295-02.xml
# Processed and wrote results for 395-02.xml
# Processed and wrote results for 274-01.xml
# Processed and wrote results for 352-05.xml
# Processed and wrote results for 309-01.xml
# Processed and wrote results for 252-05.xml
# Processed and wrote results for 307-04.xml
# Processed and wrote results for 276-04.xml
# Processed and wrote results for 278-01.xml
# Processed and wrote results for 323-05.xml
# Processed and wrote results for 287-02.xml
# Processed and wrote results for 305-01.xml
# Processed and wrote results for 366-01.xml
# Processed and wrote results for 368-04.xml
# Processed and wrote results for 399-02.xml
# Processed and wrote results for 299-02.xml
# Processed and wrote results for 299-03.xml
# Processed and wrote results for 399-03.xml
# Processed and wrote results for 240-04.xml
# Processed and wrote results for 333-01.xml
# Processed and wrote results for 287-03.xml
# Processed and wrote results for 250-01.xml
# Processed and wrote results for 350-01.xml
# Processed and wrote results for 323-04.xml
# Processed and wrote results for 223-04.xml
# Processed and wrote results for 307-05.xml
# Processed and wrote results for 252-04.xml
# Processed and wrote results for 352-04.xml
# Processed and wrote results for 321-01.xml
# Processed and wrote results for 221-01.xml
# Processed and wrote results for 395-03.xml
# Processed and wrote results for 295-03.xml
# Processed and wrote results for 242-01.xml
# Processed and wrote results for 331-04.xml
# Processed and wrote results for 242-03.xml
# Processed and wrote results for 395-01.xml
# Processed and wrote results for 295-01.xml
# Processed and wrote results for 274-02.xml
# Processed and wrote results for 321-03.xml
# Processed and wrote results for 221-03.xml
# Processed and wrote results for 309-02.xml
# Processed and wrote results for 285-04.xml
# Processed and wrote results for 278-02.xml
# Processed and wrote results for 250-03.xml
# Processed and wrote results for 350-03.xml
# Processed and wrote results for 289-04.xml
# Processed and wrote results for 287-01.xml
# Processed and wrote results for 305-02.xml
# Processed and wrote results for 366-02.xml
# Processed and wrote results for 333-03.xml
# Processed and wrote results for 299-01.xml
# Processed and wrote results for 399-01.xml
# Processed and wrote results for 397-04.xml
# Processed and wrote results for 297-04.xml
# Processed and wrote results for 297-05.xml
# Processed and wrote results for 333-02.xml
# Processed and wrote results for 366-03.xml
# Processed and wrote results for 305-03.xml
# Processed and wrote results for 350-02.xml
# Processed and wrote results for 289-05.xml
# Processed and wrote results for 250-02.xml
# Processed and wrote results for 278-03.xml
# Processed and wrote results for 285-05.xml
# Processed and wrote results for 309-03.xml
# Processed and wrote results for 221-02.xml
# Processed and wrote results for 321-02.xml
# Processed and wrote results for 274-03.xml
# Processed and wrote results for 242-02.xml
# Processed and wrote results for 331-03.xml
# Processed and wrote results for 364-02.xml
# Processed and wrote results for 395-04.xml
# Processed and wrote results for 295-04.xml
# Processed and wrote results for 285-01.xml
# Processed and wrote results for 307-02.xml
# Processed and wrote results for 252-03.xml
# Processed and wrote results for 352-03.xml
# Processed and wrote results for 323-03.xml
# Processed and wrote results for 223-03.xml
# Processed and wrote results for 276-02.xml
# Processed and wrote results for 289-01.xml
# Processed and wrote results for 368-02.xml
# Processed and wrote results for 397-01.xml
# Processed and wrote results for 297-01.xml
# Processed and wrote results for 299-04.xml
# Processed and wrote results for 399-04.xml
# Processed and wrote results for 240-03.xml
# Processed and wrote results for 240-02.xml
# Processed and wrote results for 299-05.xml
# Processed and wrote results for 368-03.xml
# Processed and wrote results for 276-03.xml
# Processed and wrote results for 223-02.xml
# Processed and wrote results for 323-02.xml
# Processed and wrote results for 352-02.xml
# Processed and wrote results for 252-02.xml
# Processed and wrote results for 307-03.xml
# Processed and wrote results for 295-05.xml
# Processed and wrote results for 395-05.xml
# Processed and wrote results for 364-03.xml
# Processed and wrote results for 331-02.xml
# Processed and wrote results for 364-01.xml
# Processed and wrote results for 242-05.xml
# Processed and wrote results for 221-05.xml
# Processed and wrote results for 274-04.xml
# Processed and wrote results for 285-02.xml
# Processed and wrote results for 307-01.xml
# Processed and wrote results for 309-04.xml
# Processed and wrote results for 278-04.xml
# Processed and wrote results for 276-01.xml
# Processed and wrote results for 305-04.xml
# Processed and wrote results for 289-02.xml
# Processed and wrote results for 368-01.xml
# Processed and wrote results for 366-04.xml
# Processed and wrote results for 297-02.xml
# Processed and wrote results for 397-02.xml
# Processed and wrote results for 240-01.xml
# Processed and wrote results for 397-03.xml
# Processed and wrote results for 297-03.xml
# Processed and wrote results for 333-04.xml
# Processed and wrote results for 250-04.xml
# Processed and wrote results for 350-04.xml
# Processed and wrote results for 289-03.xml
# Processed and wrote results for 323-01.xml
# Processed and wrote results for 278-05.xml
# Processed and wrote results for 223-01.xml
# Processed and wrote results for 252-01.xml
# Processed and wrote results for 309-05.xml
# Processed and wrote results for 352-01.xml
# Processed and wrote results for 285-03.xml
# Processed and wrote results for 321-04.xml
# Processed and wrote results for 221-04.xml
# Processed and wrote results for 242-04.xml
# Processed and wrote results for 331-01.xml
# Processed and wrote results for 356-02.xml
# Processed and wrote results for 256-02.xml
# Processed and wrote results for 303-03.xml
# Processed and wrote results for 360-03.xml
# Processed and wrote results for 335-02.xml
# Processed and wrote results for 291-05.xml
# Processed and wrote results for 391-05.xml
# Processed and wrote results for 248-02.xml
# Processed and wrote results for 339-02.xml
# Processed and wrote results for 244-02.xml
# Processed and wrote results for 272-03.xml
# Processed and wrote results for 227-02.xml
# Processed and wrote results for 327-02.xml
# Processed and wrote results for 283-04.xml
# Processed and wrote results for 327-03.xml
# Processed and wrote results for 227-03.xml
# Processed and wrote results for 272-02.xml
# Processed and wrote results for 393-01.xml
# Processed and wrote results for 293-01.xml
# Processed and wrote results for 244-03.xml
# Processed and wrote results for 339-03.xml
# Processed and wrote results for 391-04.xml
# Processed and wrote results for 248-03.xml
# Processed and wrote results for 291-04.xml
# Processed and wrote results for 335-03.xml
# Processed and wrote results for 360-02.xml
# Processed and wrote results for 281-01.xml
# Processed and wrote results for 303-02.xml
# Processed and wrote results for 256-03.xml
# Processed and wrote results for 356-03.xml
# Processed and wrote results for 325-04.xml
# Processed and wrote results for 225-04.xml
# Processed and wrote results for 256-01.xml
# Processed and wrote results for 356-01.xml
# Processed and wrote results for 358-04.xml
# Processed and wrote results for 281-03.xml
# Processed and wrote results for 258-04.xml
# Processed and wrote results for 335-01.xml
# Processed and wrote results for 246-04.xml
# Processed and wrote results for 248-01.xml
# Processed and wrote results for 339-01.xml
# Processed and wrote results for 337-04.xml
# Processed and wrote results for 244-01.xml
# Processed and wrote results for 393-03.xml
# Processed and wrote results for 293-03.xml
# Processed and wrote results for 329-04.xml
# Processed and wrote results for 327-01.xml
# Processed and wrote results for 227-01.xml
# Processed and wrote results for 254-04.xml
# Processed and wrote results for 354-04.xml
# Processed and wrote results for 301-05.xml
# Processed and wrote results for 301-04.xml
# Processed and wrote results for 254-05.xml
# Processed and wrote results for 272-01.xml
# Processed and wrote results for 293-02.xml
# Processed and wrote results for 393-02.xml
# Processed and wrote results for 337-05.xml
# Processed and wrote results for 362-04.xml
# Processed and wrote results for 360-01.xml
# Processed and wrote results for 258-05.xml
# Processed and wrote results for 281-02.xml
# Processed and wrote results for 303-01.xml
# Processed and wrote results for 325-05.xml
# Processed and wrote results for 270-04.xml
# Processed and wrote results for 325-01.xml
# Processed and wrote results for 225-01.xml
# Processed and wrote results for 358-01.xml
# Processed and wrote results for 258-01.xml
# Processed and wrote results for 256-04.xml
# Processed and wrote results for 356-04.xml
# Processed and wrote results for 335-04.xml
# Processed and wrote results for 391-03.xml
# Processed and wrote results for 248-04.xml
# Processed and wrote results for 291-03.xml
# Processed and wrote results for 246-01.xml
# Processed and wrote results for 337-01.xml
# Processed and wrote results for 339-04.xml
# Processed and wrote results for 244-04.xml
# Processed and wrote results for 327-04.xml
# Processed and wrote results for 227-04.xml
# Processed and wrote results for 229-01.xml
# Processed and wrote results for 329-01.xml
# Processed and wrote results for 283-03.xml
# Processed and wrote results for 254-01.xml
# Processed and wrote results for 354-01.xml
# Processed and wrote results for 283-02.xml
# Processed and wrote results for 301-01.xml
# Processed and wrote results for 272-04.xml
# Processed and wrote results for 227-05.xml
# Processed and wrote results for 362-01.xml
# Processed and wrote results for 291-02.xml
# Processed and wrote results for 391-02.xml
# Processed and wrote results for 360-04.xml
# Processed and wrote results for 256-05.xml
# Processed and wrote results for 303-04.xml
# Processed and wrote results for 270-01.xml
# Processed and wrote results for 225-02.xml
# Processed and wrote results for 325-02.xml
# Processed and wrote results for 270-03.xml
# Processed and wrote results for 258-02.xml
# Processed and wrote results for 358-02.xml
# Processed and wrote results for 246-02.xml
# Processed and wrote results for 337-02.xml
# Processed and wrote results for 362-03.xml
# Processed and wrote results for 293-05.xml
# Processed and wrote results for 393-05.xml
# Processed and wrote results for 329-02.xml
# Processed and wrote results for 229-02.xml
# Processed and wrote results for 301-03.xml
# Processed and wrote results for 354-02.xml
# Processed and wrote results for 254-02.xml
# Processed and wrote results for 254-03.xml
# Processed and wrote results for 354-03.xml
# Processed and wrote results for 283-01.xml
# Processed and wrote results for 301-02.xml
# Processed and wrote results for 229-03.xml
# Processed and wrote results for 329-03.xml
# Processed and wrote results for 393-04.xml
# Processed and wrote results for 293-04.xml
# Processed and wrote results for 362-02.xml
# Processed and wrote results for 337-03.xml
# Processed and wrote results for 246-03.xml
# Processed and wrote results for 391-01.xml
# Processed and wrote results for 291-01.xml
# Processed and wrote results for 358-03.xml
# Processed and wrote results for 258-03.xml
# Processed and wrote results for 270-02.xml
# Processed and wrote results for 325-03.xml
# Processed and wrote results for 225-03.xml

# %%
#Load CSV data in
csv_file_path = '/Users/yashwanthys/PersonalProjects/ML_Proj/De-Identification/fine_tuning/TestFineTunePalmBreif.csv'
cleaned_data = []

with open(csv_file_path, 'r', encoding='utf-8-sig') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        for cell in row:
            try:
                # Replace square brackets and inner double quotes that are problematic
                cell = cell.replace('["', '').replace('"]', '').replace('\\"', '"')

                # Load each cell as a JSON object
                cell_json = json.loads(cell)

                # Now that the content is clean, append to cleaned_data list
                cleaned_data.append(cell_json)
            except json.JSONDecodeError as e:
                print(f"JSON decode error for cell '{cell}': {e}")

jsonl_file_path = '/Users/yashwanthys/PersonalProjects/ML_Proj/De-Identification/fine_tuning/TestFineTunePalmBreif.jsonl'
# Write cleaned data to a JSONL file
with open(jsonl_file_path, 'w', encoding='utf-8') as jsonl_file:
    for item in cleaned_data:
        jsonl_file.write(json.dumps(item) + '\n')

# %%
#from OpenAI website to format data;  https://platform.openai.com/docs/guides/fine-tuning/preparing-your-dataset

# Next, we specify the data path and open the JSONL file

data_path = '/Users/yashwanthys/PersonalProjects/ML_Proj/De-Identification/fine_tuning/TestFineTune_detailed.jsonl'

# Load dataset
with open(data_path) as f:
    dataset = [json.loads(line) for line in f]

# We can inspect the data quickly by checking the number of examples and the first item

# Initial dataset stats
print("Num examples:", len(dataset))
print("First example:")
for message in dataset[0]["messages"]:
    print(message)

# Now that we have a sense of the data, we need to go through all the different examples and check to make sure the formatting is correct and matches the Chat completions message structure

# Format error checks
format_errors = defaultdict(int)

for ex in dataset:
    if not isinstance(ex, dict):
        format_errors["data_type"] += 1
        continue

    messages = ex.get("messages", None)
    if not messages:
        format_errors["missing_messages_list"] += 1
        continue

    for message in messages:
        if "role" not in message or "content" not in message:
            format_errors["message_missing_key"] += 1

        if any(k not in ("role", "content", "name") for k in message):
            format_errors["message_unrecognized_key"] += 1

        if message.get("role", None) not in ("system", "user", "assistant"):
            format_errors["unrecognized_role"] += 1

        content = message.get("content", None)
        if not content or not isinstance(content, str):
            format_errors["missing_content"] += 1

    if not any(message.get("role", None) == "assistant" for message in messages):
        format_errors["example_missing_assistant_message"] += 1

if format_errors:
    print("Found errors:")
    for k, v in format_errors.items():
        print(f"{k}: {v}")
else:
    print("No errors found")

# Beyond the structure of the message, we also need to ensure that the length does not exceed the 4096 token limit.

# Token counting functions
encoding = tiktoken.get_encoding("cl100k_base")

# not exact!
# simplified from https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb
def num_tokens_from_messages(messages, tokens_per_message=3, tokens_per_name=1):
    num_tokens = 0
    for message in messages:
        num_tokens += tokens_per_message
        for key, value in message.items():
            num_tokens += len(encoding.encode(value))
            if key == "name":
                num_tokens += tokens_per_name
    num_tokens += 3
    return num_tokens

def num_assistant_tokens_from_messages(messages):
    num_tokens = 0
    for message in messages:
        if message["role"] == "assistant":
            num_tokens += len(encoding.encode(message["content"]))
    return num_tokens

def print_distribution(values, name):
    print(f"\n#### Distribution of {name}:")
    print(f"min / max: {min(values)}, {max(values)}")
    print(f"mean / median: {np.mean(values)}, {np.median(values)}")
    print(f"p5 / p95: {np.quantile(values, 0.1)}, {np.quantile(values, 0.9)}")

# Last, we can look at the results of the different formatting operations before proceeding with creating a fine-tuning job:

# Warnings and tokens counts
n_missing_system = 0
n_missing_user = 0
n_messages = []
convo_lens = []
assistant_message_lens = []

for ex in dataset:
    messages = ex["messages"]
    if not any(message["role"] == "system" for message in messages):
        n_missing_system += 1
    if not any(message["role"] == "user" for message in messages):
        n_missing_user += 1
    n_messages.append(len(messages))
    convo_lens.append(num_tokens_from_messages(messages))
    assistant_message_lens.append(num_assistant_tokens_from_messages(messages))

print("Num examples missing system message:", n_missing_system)
print("Num examples missing user message:", n_missing_user)
print_distribution(n_messages, "num_messages_per_example")
print_distribution(convo_lens, "num_total_tokens_per_example")
print_distribution(assistant_message_lens, "num_assistant_tokens_per_example")
n_too_long = sum(l > 4096 for l in convo_lens)
print(f"\n{n_too_long} examples may be over the 4096 token limit, they will be truncated during fine-tuning")

# Pricing and default n_epochs estimate
MAX_TOKENS_PER_EXAMPLE = 4096

MIN_TARGET_EXAMPLES = 100
MAX_TARGET_EXAMPLES = 25000
TARGET_EPOCHS = 3
MIN_EPOCHS = 1
MAX_EPOCHS = 25

n_epochs = TARGET_EPOCHS
n_train_examples = len(dataset)
if n_train_examples * TARGET_EPOCHS < MIN_TARGET_EXAMPLES:
    n_epochs = min(MAX_EPOCHS, MIN_TARGET_EXAMPLES // n_train_examples)
elif n_train_examples * TARGET_EPOCHS > MAX_TARGET_EXAMPLES:
    n_epochs = max(MIN_EPOCHS, MAX_TARGET_EXAMPLES // n_train_examples)

n_billing_tokens_in_dataset = sum(min(MAX_TOKENS_PER_EXAMPLE, length) for length in convo_lens)
print(f"Dataset has ~{n_billing_tokens_in_dataset} tokens that will be charged for during training")
print(f"By default, you'll train for {n_epochs} epochs on this dataset")
print(f"By default, you'll be charged for ~{n_epochs * n_billing_tokens_in_dataset} tokens")

# Calculate the estimated cost for fine-tuning
cost_per_100k_tokens = 0.80  # Cost for every 100,000 tokens
estimated_cost = ((n_epochs * n_billing_tokens_in_dataset) / 100000) * cost_per_100k_tokens
print(f"Estimated cost for fine-tuning: approximately ${estimated_cost:.2f}") #I added this for actual cost based on current pricing
# Out:
# Num examples: 30
# First example:
# {'role': 'system', 'content': "Task: Please anonymize the following clinical note.\n\nSpecific Instructions: Replace all the following Protected health information (PHI) text with the '[censored]'.\n\n1) Censor any string or substring that has name, including patients, doctors, any acr"}
# {'role': 'user', 'content': "Record date: \n\n\nRecord date: 2068-12-05\n\nNarrative History\t\n\n Patient presents for uri.  Walks -in .  Overdue for follow-up by 3 months.\n\n\n\nStarted last week.   Sinus pressure, post nasal drip , headache , ears blocked.  \n\nNo fevers.\n\nSlight white nasal cdischarge.\n\n\n\nTaking advil sinus only helps transiently.\n\nNot getting better or worse.\n\nNo chest symptoms - coughing etc..\n\n\n\nGot flu shot already.\n\n\n\n\n\nProblems\n\nFH breast cancer : 37 yo s\n\nFH myocardial infarction : mother died 66 yo\n\nHypertension \n\nUterine fibroids : u/s 2062\n\nSmoking : quit 2/67 s/p MI\n\nHyperlipidemia : CRF mild chol, cigs, HTN, Fhx and known hx CAD in pt.\n\nborderline diabetes mellitus : 4/63 125 , follow hgbaic\n\nVPB : 2065 - ETT showed freq PVC's, bigeminy and couplets, nondx for ischemia\n\nCoronary artery disease : s/p ant SEMI + stent LAD 2/67, Dr Oakley, ETT Clarkfield 3/67 - neg scan for ischemia.\n\nThyroid nodule : 2065, thyroid scan 2066 consistent with hot nodule and toxic multinodular goiter, saw Dr Dolan, follow TSH. \n\n\n\n\n\nMedications\n\nAsa (ACETYLSALICYLIC Acid) 325MG, 1 Tablet(s) PO QD\n\nNitroglycerin 1/150 (0.4 Mg) 1 TAB SL x1 PRN prn CP\n\nNorvasc (AMLODIPINE) 5MG, 1 Tablet(s) PO QD\n\nPlavix (CLOPIDOGREL) 75 MG PO QD\n\nATENOLOL 50MG, 1 Tablet(s) PO QD\n\nLipitor (ATORVASTATIN) 10MG, 1 Tablet(s) PO QD\n\nHctz (HYDROCHLOROTHIAZIDE) 25MG, 1 Tablet(s) PO QD\n\nZestril (LISINOPRIL) 40MG, 1 Tablet(s) PO QD \n\n\n\n\n\nAllergies\n\nCeclor (CEFACLOR) - Rash \n\n\n\n\n\nPhysical Exam\t \n\n\t\n\nVital signs  140/82  98.2\n\nLooks well,  nontoxic\n\nSinuses - nontender\n\nTM's clear\n\nOP - negative without exudates\n\nneck- supple without increased nodes\n\nlungs - clear without wheezing on forced exp \n\nCVS - rrrs2s2\n\n \n\n\n\n\n\nAssessment and Plan\t\n\n1. URI - no evidence of bact sinus infection.  Needs decongestion but would like to avoid decong systemically given history CAD and ectopy in past. Will use steam, humidity, nasal decong spray for 3 days.  Call if fevers, worsens or persists.\n\n2. Hot thyroid nodule - was slightly higher last visit - will refer to Dr Dolan for discussion re treating this now especially given her history of cardiac ds in the last couple of years.\n\n3. blood pressure - slightly elevated above what would want it. Will recheck on follow-up which will be soon\n\n4. Chol- will check fastings next visit. Lfts okay in June\n\n\n\nDue for annual - will schedule next avail.\n\n\n\nBeverly Thiel MD\n\n\n\n"}
# {'role': 'assistant', 'content': "\n\n\nRecord date: 2068-12-05\n\nNarrative History\t\n\n Patient presents for uri.  Walks -in .  Overdue for follow-up by 3 months.\n\n\n\nStarted last week.   Sinus pressure, post nasal drip , headache , ears blocked.  \n\nNo fevers.\n\nSlight white nasal cdischarge.\n\n\n\nTaking advil sinus only helps transiently.\n\nNot getting better or worse.\n\nNo chest symptoms - coughing etc..\n\n\n\nGot flu shot already.\n\n\n\n\n\nProblems\n\nFH breast cancer : 37 yo s\n\nFH myocardial infarction : mother died 66 yo\n\nHypertension \n\nUterine fibroids : u/s 2062\n\nSmoking : quit 2/67 s/p MI\n\nHyperlipidemia : CRF mild chol, cigs, HTN, Fhx and known hx CAD in pt.\n\nborderline diabetes mellitus : 4/63 125 , follow hgbaic\n\nVPB : 2065 - ETT showed freq PVC's, bigeminy and couplets, nondx for ischemia\n\nCoronary artery disease : s/p ant SEMI + stent LAD 2/67, Dr Oakley, ETT Clarkfield 3/67 - neg scan for ischemia.\n\nThyroid nodule : 2065, thyroid scan 2066 consistent with hot nodule and toxic multinodular goiter, saw Dr Dolan, follow TSH. \n\n\n\n\n\nMedications\n\nAsa (ACETYLSALICYLIC Acid) 325MG, 1 Tablet(s) PO QD\n\nNitroglycerin 1/150 (0.4 Mg) 1 TAB SL x1 PRN prn CP\n\nNorvasc (AMLODIPINE) 5MG, 1 Tablet(s) PO QD\n\nPlavix (CLOPIDOGREL) 75 MG PO QD\n\nATENOLOL 50MG, 1 Tablet(s) PO QD\n\nLipitor (ATORVASTATIN) 10MG, 1 Tablet(s) PO QD\n\nHctz (HYDROCHLOROTHIAZIDE) 25MG, 1 Tablet(s) PO QD\n\nZestril (LISINOPRIL) 40MG, 1 Tablet(s) PO QD \n\n\n\n\n\nAllergies\n\nCeclor (CEFACLOR) - Rash \n\n\n\n\n\nPhysical Exam\t \n\n\t\n\nVital signs  140/82  98.2\n\nLooks well,  nontoxic\n\nSinuses - nontender\n\nTM's clear\n\nOP - negative without exudates\n\nneck- supple without increased nodes\n\nlungs - clear without wheezing on forced exp \n\nCVS - rrrs2s2\n\n \n\n\n\n\n\nAssessment and Plan\t\n\n1. URI - no evidence of bact sinus infection.  Needs decongestion but would like to avoid decong systemically given history CAD and ectopy in past. Will use steam, humidity, nasal decong spray for 3 days.  Call if fevers, worsens or persists.\n\n2. Hot thyroid nodule - was slightly higher last visit - will refer to Dr Dolan for discussion re treating this now especially given her history of cardiac ds in the last couple of years.\n\n3. blood pressure - slightly elevated above what would want it. Will recheck on follow-up which will be soon\n\n4. Chol- will check fastings next visit. Lfts okay in June\n\n\n\nDue for annual - will schedule next avail.\n\n\n\nBeverly Thiel MD\n\n\n\n"}
# No errors found
# Num examples missing system message: 0
# Num examples missing user message: 0
#
# #### Distribution of num_messages_per_example:
# min / max: 3, 3
# mean / median: 3.0, 3.0
# p5 / p95: 3.0, 3.0
#
# #### Distribution of num_total_tokens_per_example:
# min / max: 666, 3246
# mean / median: 1481.9666666666667, 1440.0
# p5 / p95: 903.5, 2100.7000000000003
#
# #### Distribution of num_assistant_tokens_per_example:
# min / max: 278, 1574
# mean / median: 698.4, 677.0
# p5 / p95: 409.6, 999.1000000000001
#
# 0 examples may be over the 4096 token limit, they will be truncated during fine-tuning
# Dataset has ~44459 tokens that will be charged for during training
# By default, you'll train for 3 epochs on this dataset
# By default, you'll be charged for ~133377 tokens
# Estimated cost for fine-tuning: approximately $1.07
